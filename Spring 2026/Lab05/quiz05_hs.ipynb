# %% [markdown]
# # 📝 Quiz 05 — Probability, Simulation & Hypothesis Testing
#
# <div style="background:#fff3cd;border-left:6px solid #ffc107;padding:12px 16px;border-radius:6px;margin:10px 0;">
# <b>Instructions</b>
# <ul>
# <li>You may use your lab notebooks and course notes.</li>
# <li>Work independently — no collaboration or internet searches.</li>
# <li><b>10 questions are randomly selected from a bank of 34</b> —
#     every student sees a different subset.</li>
# <li><b>One attempt per question.</b> Feedback appears immediately after each answer.</li>
# <li>The quiz locks the moment you run the quiz cell.
#     Restarting the kernel will not give you a new set of questions or another attempt.</li>
# <li>Click <b>Submit Quiz</b> when finished.</li>
# </ul>
# </div>

# %% [markdown]
# ### Step 1 — Enter your name and run setup

# %%
from lab05_init import *        # loads apply_style, user, etc.
from stemds_quiz import open_quiz

name = "..."                    # ← enter your name here

# %% [markdown]
# ### Step 2 — Run this cell to open your quiz

# %%
result = open_quiz(
    "questions_quiz05_hs.json",
    name, user,
    quiz_id      = "Quiz05_HS",
    max_attempts = 1,
    n_questions  = 10,          # 10 drawn randomly from 34
)

# %% [markdown]
# ### Step 3 — Submit when finished

# %%
from lab_submit_canvas import submit_quiz

score, total = result
submit_quiz(name, user, score, total, quiz_id="Quiz05_HS")
