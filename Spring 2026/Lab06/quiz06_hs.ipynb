# %% [markdown]
# # 📝 Quiz 06 — Simulation, Tables & Text Analysis
#
# <div style="background:#fff3cd;border-left:6px solid #ffc107;padding:12px 16px;border-radius:6px;margin:10px 0;">
# <b>Instructions</b>
# <ul>
# <li>You may use your lab notebooks and course notes.</li>
# <li>Work independently — no collaboration or internet searches.</li>
# <li><b>12 questions randomly selected from a bank of 29.</b>
#     Every student sees a different subset.</li>
# <li><b>One attempt per question.</b> Feedback appears immediately.</li>
# <li>The quiz locks the moment you run the quiz cell.
#     Restarting the kernel will not change your questions or reset attempts.</li>
# <li>Click <b>Submit Quiz</b> when finished.</li>
# </ul>
# </div>
#
# **Topics covered:**
# - `np.random.choice` and `np.arange` for simulation
# - D&D die rolling and modifier estimation
# - `datascience` Tables — sort, where, with_columns, method chaining
# - DNA GC content sliding window
# - Python dictionaries — lookup, counting, sorting
# - Text analysis — split, stop words, word frequency
# - Lab 5 review — hypothesis testing, p-values, groundhog simulation

# %% [markdown]
# ### Step 1 — Setup

# %%
from lab06_init import *        # loads apply_style, user, etc.
from stemds_quiz import open_quiz

name = "..."                    # ← enter your name here

# %% [markdown]
# ### Step 2 — Open quiz

# %%
result = open_quiz(
    "questions_quiz06.json",
    name, user,
    quiz_id      = "Quiz06_HS",
    max_attempts = 1,
    n_questions  = 12,          # 12 drawn randomly from 29
)

# %% [markdown]
# ### Step 3 — Submit

# %%
from lab_submit_canvas import submit_quiz

score, total = result
submit_quiz(name, user, score, total, quiz_id="Quiz06_HS")
