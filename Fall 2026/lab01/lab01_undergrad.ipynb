# %% [markdown]
# <img src="Temple_flag_morn.png" style="width:160px;float:right;margin:8px;"/>
#
# # 🧪 Lab 01: Your First Python Code
# ---
# **What you'll learn today:**
# - What a Jupyter notebook is and how to use it
# - How to store information in Python *variables*
# - How to do arithmetic with Python
# - How to check your work with automated tests
#
# The core Questions build the skills you'll use every week. The **Challenges** section near the
# end applies those same skills to slightly longer, multi-step problems — the kind you'll run into
# in real analyses.

# %%
# 🔧 Run this cell first! (Shift+Enter)
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..", "shared-public")))
from init import *

# %%
# 🔖 Lab version — do not edit. Used by the automated checks below.
ver = '2026V101'

# %% [markdown]
# ## 📓 How This Notebook Works
#
# A Jupyter notebook is made of **cells**. There are two kinds:
#
# | Cell type | What it contains | How to spot it |
# |-----------|-----------------|----------------|
# | **Markdown** | Text, images, instructions | Looks like a document |
# | **Code** | Python instructions for the computer | Has `In [ ]:` on the left |
#
# **To run a cell:** click it, then press **Shift + Enter** ⬆️↵
#
# <img src="intro_jupyter_images/toolbar.png" style="width:500px;margin:10px 0;"/>
#
# The dropdown in the toolbar shows you which type of cell is selected.
#
# <img src="intro_jupyter_images/typecell.png" style="width:500px;margin:10px 0;"/>

# %% [markdown]
# ## 🟢 Question 0 — Hello, World
#
# Every programmer's first program says hello to the world.
# The `print()` function displays a message on screen.
#
# **👉 Replace the `...` below with a message of your own, then run the cell.**

# %%
print("...")

# %%
# ✅ Check Question 0
check('tests_01/q0.py')

# %% [markdown]
# ## 🏷️ Variables — Storing Information
#
# A **variable** is a labeled container where Python stores a piece of information — the
# programming equivalent of recording a value in a lab notebook.
#
# ```python
# sample_name = "A-3"   # the container is called sample_name, it holds the text A-3
# ```
#
# Text stored in a variable is called a **string** — it's always wrapped in quotes.
#
# **👉 Replace `'...'` with your own name (keep the quotes!):**

# %%
# 🔵 Your name as a string variable
name = '...'   # Replace ... with your name, e.g.  name = 'Alex'

print("Hello,", name)

# %%
check('tests_01/q1a.py')

# %% [markdown]
# ## 🔤 Strings
#
# You can use **single quotes** `'like this'` or **double quotes** `"like this"` — both work!
#
# This lets you include a quote character *inside* a string:
#
# ```python
# observation = 'The technician noted "no visible growth."'
# ```
#
# **👉 Fill in your first and last name below:**

# %%
first_name = ...   # e.g.  first_name = 'Alex'
last_name  = ...   # e.g.  last_name  = 'Smith'

print(first_name, last_name)

# %%
check('tests_01/q1a2.py')

# %% [markdown]
# ### 📝 Quick Check — Variables & Strings
#
# Test what you've learned about variables:

# %%
with open("questions01C.json","r") as f:
    display_quiz(json.load(f))

# %% [markdown]
# ## 🔢 Numbers and Math
#
# Python evaluates arithmetic exactly like a calculator:
#
# | Symbol | Meaning | Example |
# |--------|---------|---------|
# | `+` | add | `3 + 2` → 5 |
# | `-` | subtract | `10 - 4` → 6 |
# | `*` | multiply | `5 * 3` → 15 |
# | `/` | divide | `10 / 4` → 2.5 |
# | `**` | power / exponent | `2 ** 8` → 256 |
#
# Try running the cells below:

# %%
# How many seconds in a day?
60 * 60 * 24

# %%
# Powers are written with **
2 ** 10   # 2 to the power of 10

# %% [markdown]
# ### 📝 Quick Check — Cell Types
#
# Answer these questions about what you've learned so far:

# %%
with open("questions01B.json", "r") as file:
    questions = json.load(file)
display_quiz(questions)

# %% [markdown]
# ### 📝 Quick Check — Python Arithmetic
#
# Test your Python math skills:

# %%
with open("questions01D.json","r") as f:
    display_quiz(json.load(f))

# %% [markdown]
# ## 🧮 Question 1 — Python as a Calculator
#
# The year **2026** can be calculated from this expression:
#
# $$5 \times \left(4 + \frac{10}{11}\right) - 49\frac{1}{3} + 2^{11} + \frac{26}{33} + 2$$
#
# Breaking a calculation into named steps — instead of one unreadable line — makes it far easier
# to check your work and to spot mistakes. Here's the start; finish it:
#
# ```python
# term1 = 5 * (4 + 10/11)
# term2 = 49 + 1/3
# term3 = 2 ** 11
# term4 = 26/33
# ```
#
# **👉 Assign `expression` to the full calculation. It should equal 2026.**
#
# *Hint: `expression = term1 - term2 + term3 + term4 + 2`*

# %%
term1 = 5 * (4 + 10/11)
term2 = 49 + (1/3)
term3 = 2 ** 11
term4 = 26/33

expression = ...   # combine the terms here!
expression

# %%
check('tests_01/q1.py')

# %% [markdown]
# ## ✅ How the Check Cells Work
#
# When you run a `check(...)` cell, gofer tests your answer automatically.
#
# **All tests passed:**
#
# <img src="intro_jupyter_images/checkpass.png" style="width:500px;margin:8px 0;"/>
#
# **Some tests failed:**
#
# <img src="intro_jupyter_images/checkfail.png" style="width:600px;margin:8px 0;"/>
#
# **If you get an error message**, don't panic — it just means something needs fixing!
#
# <img src="intro_jupyter_images/error.jpg" style="width:600px;margin:8px 0;"/>
#
# Read the error, fix your code, and run the cell again. 🔄

# %% [markdown]
# ## 🚀 Challenges
#
# The three problems below use exactly the same tools as Question 1 — variables and arithmetic —
# but each takes several steps to set up. Break each one into named intermediate variables the
# way `term1`–`term4` did above; resist the urge to cram everything onto one line.

# %% [markdown]
# <div class="challenge-box">📏 <b>Challenge 1 — Average Distance.</b> Variables let you break a
# problem into readable steps. Imagine everyone at your lab table lives some distance from campus
# (in miles). For example:
#
# - Person 1: 0.5 miles
# - Person 2: 1.2 miles
# - Person 3: 3.0 miles
# - Person 4: 0.8 miles
# - Person 5: 2.1 miles
#
# Edit the distances below to match your own group (or make up numbers), then compute
# <code>average_distance</code>.</div>

# %%
# 🔵 Replace these distances with your group's actual distances
d1 = 0.5
d2 = 1.2
d3 = 3.0
d4 = 0.8
d5 = 2.1

sum_distance  = d1 + d2 + d3 + d4 + d5
average_distance = ...   # divide sum_distance by number of people

print(f"Total distance:   {sum_distance:.2f} miles")
print(f"Average distance: {average_distance:.2f} miles")

# %%
check('tests_01/q1b.py')

# %% [markdown]
# <div class="challenge-box">⏱️ <b>Challenge 2 — Seconds Since 2000.</b> How many seconds have
# passed since midnight on <b>January 1, 2000</b>, through midnight on <b>January 1, 2026</b>?
#
# Strategy — break it into steps:
#
# 1. How many seconds in a minute? → <code>60</code>
# 2. How many seconds in an hour? → <code>60 * 60</code>
# 3. How many seconds in a day? → <code>60 * 60 * 24</code>
# 4. How many days in a year? (most years have 365, but <b>leap years</b> have 366)
# 5. Between 2000 and 2026 there were <b>7 leap years</b> and <b>19 regular years</b>
#
# Assign <code>seconds_since_2000</code> using Python arithmetic.</div>

# %%
# 🔵 Compute seconds since Jan 1, 2000 through Jan 1, 2026
# Hint: total days = (19 * 365) + (7 * 366)

seconds_since_2000 = ...

print(f"Seconds since 2000: {seconds_since_2000:,}")

# %%
check('tests_01/q2.py')

# %% [markdown]
# <div class="challenge-box">📄 <b>Challenge 3 — Paper Folding.</b> A single sheet of paper is
# <b>0.1 mm thick</b>. If you could fold a piece of paper in half <b>27 times</b>, each fold would
# double the thickness. After 27 folds, how tall would the stack be <b>in kilometers</b>?
#
# Hint:
#
# - After 1 fold → 2 sheets thick
# - After 2 folds → 4 sheets thick
# - After <i>n</i> folds → <code>2**n</code> sheets thick
# - Convert: 1 km = 1,000,000 mm
#
# Calculate <code>bundle_height_km</code>.</div>

# %%
paper_thickness_mm = 0.1
num_folds = 27

# 🔵 Calculate height in km after 27 folds
bundle_height_km = ...

print(f"Height after {num_folds} folds: {bundle_height_km:.2f} km")
print(f"(Mount Everest is 8.8 km tall!)")

# %%
check('tests_01/q3.py')

# %% [markdown]
# ## 💬 Question 4 — Reflection
#
# Think about what you did in this lab and answer the questions below.
#
# - What was your favorite part?
# - Which Challenge was trickiest? How did you figure it out?
# - How might variables and arithmetic like this show up in your own field of study?
#
# **Put your answer in the markdown cell below**

# %% [markdown]
# *Your answer here — double-click this cell to edit it, then Shift+Enter to save.*

# %%
# BE SURE TO SAVE YOUR NOTEBOOK BEFORE RUNNING THIS TEST (Ctrl+S or Cmd+S)
check('tests_01/q4_open_ended.py')

# %% [markdown]
# ## 🏁 Final Step — Check, Submit to Canvas, Then Submit Lab
#
# Follow these three steps **in order**:
#
# 1. ✅ **Run the cell below** to test all your answers and see your score.
# 2. 📤 **Upload to Canvas.** Download your notebook as a `.ipynb` file ([instructions](https://laserchemist.github.io/data/submission-instructions.html#ipynb)) and export an HTML copy ([instructions](https://laserchemist.github.io/data/submission-instructions.html#html)), then upload that HTML file to this lab's Canvas assignment.
# 3. 🚀 **Only then run the final cell and click Submit Lab.** This records your score to the course gradebook — treat it as confirmation that steps 1 and 2 are already done.

# %%
# Run all tests at once
from gofer.ok import check
correct = 0
questions = ["0", "1a", "1a2", "1", "1b", "2", "3", "4_open_ended"]
for x in questions:
    print(f"Testing question {x}:")
    display(check(f"tests_01/q{x}.py"))
    if check(f"tests_01/q{x}.py").grade == 1.0:
        correct += 1

# %%
from lab_submit import submit_lab
submit_lab(name, user, correct, questions, lab_id="Lab01")
